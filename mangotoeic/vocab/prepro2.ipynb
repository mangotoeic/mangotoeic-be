# %%
import pandas as pd

# %%
df2 = pd.read_csv("../corpus/data/problemcorpus.csv")

# %%
df2=df2['corpus'].str.lower()
df2
# Out:
# 0       the assets of marble faun publishing company s...
# 1       lndie film director luke steele will be in lon...
# 2       laboratory employees are expected to wear a na...
# 3       the latest training guide contains tips on tea...
# 4       once you have your resume with references and ...
#                               ...
# 3620    all employees should back up crucial data befo...
# 3621    a label on each box should indicate the produc...
# 3622    ms. jha assured the client that she would deli...
# 3623    during negotiations, management appeared agree...
# 3624    employees across several departments have been...
# Name: corpus, Length: 3625, dtype: object

# %%
df2.to_csv("lower.csv")

# %%
df2=df2.str.replace(',','')
df2
# Out:
# 0       the assets of marble faun publishing company s...
# 1       lndie film director luke steele will be in lon...
# 2       laboratory employees are expected to wear a na...
# 3       the latest training guide contains tips on tea...
# 4       once you have your resume with references and ...
#                               ...
# 3620    all employees should back up crucial data befo...
# 3621    a label on each box should indicate the produc...
# 3622    ms. jha assured the client that she would deli...
# 3623    during negotiations management appeared agreea...
# 3624    employees across several departments have been...
# Name: corpus, Length: 3625, dtype: object

# %%
df2=df2.str.replace('.','')
df2
# Out:
# 0       the assets of marble faun publishing company s...
# 1       lndie film director luke steele will be in lon...
# 2       laboratory employees are expected to wear a na...
# 3       the latest training guide contains tips on tea...
# 4       once you have your resume with references and ...
#                               ...
# 3620    all employees should back up crucial data befo...
# 3621    a label on each box should indicate the produc...
# 3622    ms jha assured the client that she would deliv...
# 3623    during negotiations management appeared agreea...
# 3624    employees across several departments have been...
# Name: corpus, Length: 3625, dtype: object

# %%
df2=df2.str.replace(r'[!?\.\'\"\-\_\@\$\,\:\[\]\(\)\{\}0-9]',' ')
df2
# Out:
# 0       the assets of marble faun publishing company s...
# 1       lndie film director luke steele will be in lon...
# 2       laboratory employees are expected to wear a na...
# 3       the latest training guide contains tips on tea...
# 4       once you have your resume with references and ...
#                               ...
# 3620    all employees should back up crucial data befo...
# 3621    a label on each box should indicate the produc...
# 3622    ms  jha assured the client that she would deli...
# 3623    during negotiations  management appeared agree...
# 3624    employees across several departments have been...
# Name: corpus, Length: 3625, dtype: object

# %%
df2.to_csv('no특수문자.csv')

# %%
df2=df2.str.cat(sep=' ')
df2
# Out:
#  and satisfying  complaints about its new line of kitchen appliances led loxevo  inc   to adopt higher standards for assessing quality  the chief engineer noted that constructing another bridge would be more economical than repairing the existing structure  jansen bus company drivers are expected to complete regular trainings in addition to maintaining their state licenses  ms  desoto had urged all employees to come to last week s budget meeting even though only officers were obligated to attend  the new interns have been very mindful of our parking regulations  to help the arts center improve its programming  please indicate which aspect of the workshop was most informative   mr  gupta explained the of benefits the upgraded customer database to the sales team  buses leaving the city terminal were delayed due to icy conditions on the roads  if you have recently purchased a digital camera and want to learn how to use it  this course is for you  the upcoming renovation of tantino airpo
# ...

# %%
type(df2)
# Out:
# str

# %%
mylist=df2.split(' ')

# %%
myset= set(mylist)

# %%
myset
# Out:
# {'',
#  'tracker',
#  'lloyd',
#  'instructor',
#  'yourmoney',
#  'excluding',
#  'stability',
#  'paintings',
#  'entrusted',
#  'kept',
#  'cups',
#  'braun',
#  'spa',
#  'league',
#  'commence',
#  'purchasing',
#  'provision',
#  'comment',
#  'include',
#  'reliably',
#  'port',
#  'dinner',
#  'recall',
#  'coffeehouse',
#  'wouldn',
#  'searching',
#  'lopez',
#  'selfservice',
#  'ofa',
#  'underdeveloped',
#  'poets',
#  'constructive',
#  'someresearch',
#  'obviously',
#  'running',
#  'residents',
#  'easiest',
#  'abouttheir',
#  'control',
#  'promiseddelivery',
#  'models',
#  'soo',
#  'cartridges',
#  'whatever',
#  'typewriter',
#  'alltime',
#  'assist',
#  'laval',
#  'lowered',
#  'steel',
#  'faraday',
#  'submissions',
#  'leader',
#  'diagnosis',
#  'helping',
#  'knownalgebra',
#  'reach',
#  'ticketholders',
#  'professions',
#  'shares',
#  'realestate',
#  'mato',
#  'dismissal',
#  'cortex',
#  'clayton',
#  'physicists',
#  'searched',
#  'airline',
# ...
